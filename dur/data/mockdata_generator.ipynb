# %%
# !pip install drawdata
# Out:
# Requirement already satisfied: drawdata in c:\users\jjaramil\appdata\local\anaconda3\envs\agents_env\lib\site-packages (0.5.0)
# Requirement already satisfied: anywidget>=0.9.2 in c:\users\jjaramil\appdata\local\anaconda3\envs\agents_env\lib\site-packages (from drawdata) (0.9.21)
# Requirement already satisfied: ipywidgets>=7.6.0 in c:\users\jjaramil\appdata\local\anaconda3\envs\agents_env\lib\site-packages (from anywidget>=0.9.2->drawdata) (8.1.8)
# Requirement already satisfied: psygnal>=0.8.1 in c:\users\jjaramil\appdata\local\anaconda3\envs\agents_env\lib\site-packages (from anywidget>=0.9.2->drawdata) (0.15.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\jjaramil\appdata\local\anaconda3\envs\agents_env\lib\site-packages (from anywidget>=0.9.2->drawdata) (4.15.0)
# Requirement already satisfied: comm>=0.1.3 in c:\users\jjaramil\appdata\local\anaconda3\envs\agents_env\lib\site-packages (from ipywidgets>=7.6.0->anywidget>=0.9.2->drawdata) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\jjaramil\appdata\local\anaconda3\envs\agents_env\lib\site-packages (from ipywidgets>=7.6.0->anywidget>=0.9.2->drawdata) (9.9.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\jjaramil\appdata\local\anaconda3\envs\agents_env\lib\site-packages (from ipywidgets>=7.6.0->anywidget>=0.9.2->drawdata) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\jjaramil\appdata\local\anaconda3\envs\agents_env\lib\site-packages (from ipywidgets>=7.6.0->anywidget>=0.9.2->drawdata) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\jjaramil\appdata\local\anaconda3\envs\agents_env\lib\site-packages (from ipywidgets>=7.6.0->anywidget>=0.9.2->drawdata) (3.0.16)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\jjaramil\appdata\local\anaconda3\envs\agents_env\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.2->drawdata) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in c:\users\jjaramil\appdata\local\anaconda3\envs\agents_env\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.2->drawdata) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\jjaramil\appdata\local\anaconda3\envs\agents_env\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.2->drawdata) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\users\jjaramil\appdata\local\anaconda3\envs\agents_env\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.2->drawdata) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in c:\users\jjaramil\appdata\local\anaconda3\envs\agents_env\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.2->drawdata) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\jjaramil\appdata\local\anaconda3\envs\agents_env\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.2->drawdata) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in c:\users\jjaramil\appdata\local\anaconda3\envs\agents_env\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.2->drawdata) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\jjaramil\appdata\local\anaconda3\envs\agents_env\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.2->drawdata) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\jjaramil\appdata\local\anaconda3\envs\agents_env\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.2->drawdata) (0.5.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\jjaramil\appdata\local\anaconda3\envs\agents_env\lib\site-packages (from jedi>=0.18.1->ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.2->drawdata) (0.8.5)
# Requirement already satisfied: executing>=1.2.0 in c:\users\jjaramil\appdata\local\anaconda3\envs\agents_env\lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.2->drawdata) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\jjaramil\appdata\local\anaconda3\envs\agents_env\lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.2->drawdata) (3.0.1)
# Requirement already satisfied: pure_eval in c:\users\jjaramil\appdata\local\anaconda3\envs\agents_env\lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.2->drawdata) (0.2.3)

# %%
from datetime import datetime
from drawdata import ScatterWidget

widget = ScatterWidget(height=200, width=200)

# %%
widget

# %%
df = widget.data_as_pandas[["x", "y", "label"]]
df["timestamp"] = datetime.now()
df.to_csv("data_sample.csv", index=False)
df.describe()
# Out:
#                 x           y                   timestamp
# count   89.000000   89.000000                          89
# mean    93.100778   96.272570  2026-02-25 17:22:08.146823
# min     12.374742   13.491619  2026-02-25 17:22:08.146823
# 25%     50.850116   55.152548  2026-02-25 17:22:08.146823
# 50%     89.745493   91.786146  2026-02-25 17:22:08.146823
# 75%    138.434626  138.574971  2026-02-25 17:22:08.146823
# max    180.596855  180.936061  2026-02-25 17:22:08.146823
# std     50.018468   49.355336                         NaN
